# %%
import pathlib
from pprint import pprint as print

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import calcium_bflow_analysis.dff_analysis_and_plotting.plot_cells_and_traces as plot_cells_and_traces
import calcium_bflow_analysis.single_fov_analysis as single_fov
from calcium_bflow_analysis.analog_trace import AnalogAcquisitionType
from calcium_bflow_analysis.fluo_metadata import FluoMetadata

# %%
foldername = pathlib.Path('/data/Hagai/WFA_InVivo/')
tifs = [
    foldername / 'z300_7.tif',
    foldername / 'z400_4.tif',
    foldername / 'z200_4.tif',
]
ch1s = [
    foldername / 'z300_7_CHANNEL_1.tif',
    foldername / 'z400_4_CHANNEL_1.tif',
    foldername / 'z200_4_CHANNEL_1.tif',
]
results = [
    foldername / 'z300_7_CHANNEL_1_results.npz',
    foldername / 'z400_4_CHANNEL_1_results.npz',
    foldername / 'z200_4_CHANNEL_1_results.npz',
]
analogs =  [
    foldername / 'z300_7_analog.txt',
    foldername / 'z400_4_analog.txt',
    foldername / 'z200_4_analog.txt',
]

# %%
fig = plot_cells_and_traces.show_side_by_side(ch1s, results)

# %%
fig.savefig(foldername / 'side_by_side.png', transparent=True, dpi=300)

# %%
meta = FluoMetadata(tifs[0])
meta.get_metadata()
print(meta)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-02c588d3c41b> in <module>
#       1 meta = FluoMetadata(tifs[0])
# ----> 2 meta.get_metadata()
#       3 print(meta)
#
# /data/MatlabCode/PBLabToolkit/CalciumDataAnalysis/python-ca-analysis-bloodflow/calcium_bflow_analysis/fluo_metadata.py in get_metadata(self)
#      28
#      29     def get_metadata(self):
# ---> 30         self._get_si_meta()
#      31         self.mouse_id = str(self._get_meta_using_regex(self.id_reg))
#      32         self.day = int(self._get_meta_using_regex(self.day_reg))
#
# /data/MatlabCode/PBLabToolkit/CalciumDataAnalysis/python-ca-analysis-bloodflow/calcium_bflow_analysis/fluo_metadata.py in _get_si_meta(self)
#      39             with tifffile.TiffFile(str(self.fname)) as f:
#      40                 si_meta = f.scanimage_metadata
# ---> 41                 self.fps = self._round_fps(float(si_meta['FrameData']['SI.hRoiManager.scanFrameRate']))
#      42                 save_chans = si_meta['FrameData']['SI.hChannels.channelSave']
#      43                 if type(save_chans) is int:
#
# KeyError: 'FrameData'

# %%
fov = single_fov.SingleFovParser(analogs[0], results[0], metadata=meta, analog=AnalogAcquisitionType.TREADROWS)

# %%
fov.parse()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-b26cd61479c0> in <module>
# ----> 1 fov.parse()
#
# /data/MatlabCode/PBLabToolkit/CalciumDataAnalysis/python-ca-analysis-bloodflow/calcium_bflow_analysis/single_fov_analysis.py in parse(self)
#      61                 sep="\t",  # old data format is \t
#      62             )
# ---> 63             self.analog_analyzed = analog_trace_runner(
#      64                 self.metadata.fname,
#      65                 analog_data,
#
# /data/MatlabCode/PBLabToolkit/CalciumDataAnalysis/python-ca-analysis-bloodflow/calcium_bflow_analysis/analog_trace.py in analog_trace_runner(tif_filename, analog_trace, analog_type, metadata, occluder, occ_metadata)
#      73     else:
#      74         raise TypeError("Invalid analog acquisition type")
# ---> 75     analysis.run()
#      76     return analysis
#      77
#
# /data/MatlabCode/PBLabToolkit/CalciumDataAnalysis/python-ca-analysis-bloodflow/calcium_bflow_analysis/analog_trace.py in run(self)
#     397
#     398     def run(self):
# --> 399         self.num_of_lines, self.num_of_frames = self._get_metadata()
#     400         stim_and_juxta_vec = self._turn_analog_vec_into_per_frame(
#     401             self.analog_trace.stimulus
#
# /data/MatlabCode/PBLabToolkit/CalciumDataAnalysis/python-ca-analysis-bloodflow/calcium_bflow_analysis/analog_trace.py in _get_metadata(self)
#     258         with tifffile.TiffFile(str(self.tif_filename)) as f:
#     259             meta = f.scanimage_metadata
# --> 260         num_of_lines = int(meta["FrameData"]["SI.hRoiManager.linesPerFrame"])
#     261         num_of_frames = int(meta["FrameData"]["SI.hStackManager.framesPerSlice"])
#     262         return num_of_lines, num_of_frames
#
# TypeError: 'NoneType' object is not subscriptable
