# %%
from roipoly import roipoly
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import h5py
# %matplotlib auto
# Out:
# Using matplotlib backend: nbAgg

# %%
filename = r'/data/Hagai/Multiscaler/21-12-17/flies_21_12_17/fly4_gevi/start_pmt_stop1_puff_stop2_lines_512px003.hdf5'

# %%
with h5py.File(filename) as f:
    data = np.array(f['/Full Stack/Channel 1'])
    
data.shape
# Out:
# (1080, 512, 512)

# %%
summed_image = np.sum(data, axis=0)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(summed_image, cmap='gray')
roi = roipoly(roicolor='b')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
mask = roi.getMask(summed_image)
trace = np.mean(data[:, mask], axis=-1)

# %%
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
ax2.plot(trace.T)
# Out:
# <img src="data:image/png;base64,..." width="432">
